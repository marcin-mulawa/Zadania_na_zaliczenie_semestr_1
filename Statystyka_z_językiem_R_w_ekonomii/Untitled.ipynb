# %%
library("dplyr")
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
data <- read.csv2('fulldata.csv', encoding = 'UTF-8')
mydlo90 <- read.csv2('mydlo90.csv', encoding = 'UTF-8')

# %%
# Out:
#   [1] "Nazwa"
#   [2] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2006..zl."
#   [3] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2007..zl."
#   [4] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2008..zl."
#   [5] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2009..zl."
#   [6] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2010..zl."
#   [7] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2011..zl."
#   [8] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2012..zl."
#   [9] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2013..zl."
#  [10] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2014..zl."
#  [11] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2015..zl."
#  [12] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2016..zl."
#  [13] "styczen.mieso.wolowe.bez.kosci..z.udzca....za.1.kg.cena.2017..zl."
# ...

# %%
wolowe <- select(data, matches('wolowe|Nazwa'))
wieprzowe <- select(data, matches('wieprzowe|Nazwa'))
mydlo <- select(data, matches('mydlo|Nazwa'))
cytryny <- select(data, matches('cytryny|Nazwa'))
jaja <- select(data, matches('jaja|Nazwa'))
garnitur <- select(data, matches('garnitur|Nazwa'))
lekarz <- select(data, matches('lekarz|Nazwa'))
smietana <- select(data, matches('smietana|Nazwa'))
wedzona <- select(data, matches('wedzona|Nazwa'))
suszona <- select(data, matches('suszona|Nazwa'))

# %%
length(wolowe[,])
# Out:
# [1] 169
